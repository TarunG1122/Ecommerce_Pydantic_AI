# %%
1+1
# Out:
# 2

# %%
from pymongo import MongoClient

# %%
client= MongoClient("mongodb+srv://taz3543_db_user:7lFS7oNZWhllVB4M@cluster0.jsdeorp.mongodb.net")

# %%
db = client["test_ecom_db"]

collection = db["products"]
print("working")
# Out:
# working

# %%
product = {

    "name": "mens casual shirt",
    "price": 999,
    "category":"men"
}

collection.insert_one(product)
# Out:
# InsertOneResult(ObjectId('6a645fe0a0c824fd2fe3b372'), acknowledged=True)
